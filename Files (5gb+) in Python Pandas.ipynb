# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/LENOVO/Downloads/2019-Nov.csv', chunksize=100000)

# %%
output = pd.DataFrame()
for chunk in df:
    categories = ['brand','category_code','event_type']
    details = chunk[categories]
    details['count'] = 1
    summary = details.groupby(categories).sum().reset_index()
    output = output.append(summary, ignore_index=True)
    #display(summary.head())
    #break
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# ...
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16112\888570455.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output = output.append(summary, ignore_index=True)

# %%
output.head()
# Out:
#   brand       category_code event_type  count
# 0  acer     accessories.bag       view      3
# 1  acer   computers.desktop   purchase      1
# 2  acer   computers.desktop       view    144
# 3  acer  computers.notebook       cart      9
# 4  acer  computers.notebook   purchase     13

# %%
final_output = output.groupby(categories).sum().reset_index()

# %%
final_output.sort_values('count')
# Out:
#         brand               category_code event_type    count
# 1217    bosch    construction.tools.screw   purchase        1
# 7008    rovus             appliances.iron       cart        1
# 7006    rovus  appliances.environment.fan       cart        1
# 7001   rovigo          apparel.shoes.keds       cart        1
# 3772   hottek  appliances.personal.scales   purchase        1
# ...       ...                         ...        ...      ...
# 6036     oppo      electronics.smartphone       view   747048
# 3863   huawei      electronics.smartphone       view  1141291
# 8972   xiaomi      electronics.smartphone       view  3074135
# 434     apple      electronics.smartphone       view  4131276
# 7164  samsung      electronics.smartphone       view  4661498
#
# [9165 rows x 4 columns]

# %%
final_output.to_csv('aggregated-consumer-info-Nov-2019.csv', index=False)
